# %% [markdown]
# # Shanzae Khan
# ---
# ## 9/8/2026
# ---
# **CMP 262 – Data Science Programming**

# %% [markdown]
# ## Output and Display
# ---

# %%
print("name:\nShanzae Khan")
print("")
print("major:\nComputer Science")
print("")
print("favorite number:\n7")
print("")
print("reason for interest in Data Science:\nI find organizing data interesting and I love coding!")
# Out:
# name:
# Shanzae Khan
#
# major:
# Computer Science
#
# favorite number:
# 7
#
# reason for interest in Data Science:
# I find organizing data interesting and I love coding!

# %% [markdown]
# ## User Input
# ---

# %%
name = input("What is your name?")
age = int(input("What is your age?"))
proglang = input("What is your favorite Programming Language?")

# %% [markdown]
# ## Calculations
# ---

# %%
num1 = int(input("Enter number 1: "))
num2 = int(input("Enter number 2: "))
num3 = int(input("Enter number 3: "))

s=(num1 + num2 + num3)
print("sum=\n",s)
print("")
a=(s/3)
print("average=\n",a)
large=max(num1,num2,num3)
print("largest value= ",large)
print("")
small=min(num1,num2,num3)
print("smallest value= ",small)
# Out:
# sum=
#  14
#
# average=
#  4.666666666666667
# largest value=  5
#
# smallest value=  4
